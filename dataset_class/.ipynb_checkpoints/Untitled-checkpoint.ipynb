# %%
import pandas as pd

# %%
tmp_df1 = pd.read_csv('./data_folder/SDDB2_2M_75/SDDB2_prompt.csv')
tmp_df2 = pd.read_csv('./data_folder/ChatGPT_SDDB2/chatgpt_prompt.csv')
tmp_df3 = pd.read_csv('./data_folder/90k_public/nine_thousand_prompt.csv')
tmp_df4 = pd.read_csv('./data_folder/30k_public/three_thousand_prompt.csv')

# %%
tmp_df1
# Out:
#                                                image_name  \
# 0       ./data_folder/SDDB2_2M_75/SDDB2-images/dc71658...
# 1       ./data_folder/SDDB2_2M_75/SDDB2-images/9341f9e...
# 2       ./data_folder/SDDB2_2M_75/SDDB2-images/e37dbf7...
# 3       ./data_folder/SDDB2_2M_75/SDDB2-images/b5e3502...
# 4       ./data_folder/SDDB2_2M_75/SDDB2-images/09c1745...
# ...                                                   ...
# 192501  ./data_folder/SDDB2_2M_75/SDDB2-images/1705f1a...
# 192502  ./data_folder/SDDB2_2M_75/SDDB2-images/6b2aecf...
# 192503  ./data_folder/SDDB2_2M_75/SDDB2-images/874b578...
# 192504  ./data_folder/SDDB2_2M_75/SDDB2-images/4ff9bba...
# 192505  ./data_folder/SDDB2_2M_75/SDDB2-images/605ae61...
#
#                                                    prompt
# 0           only memories remain, trending on artstation
# 1       a painting by edward hopper of a group of men ...
# 2       a painting by edward hopper of a glowing human...
# ...

# %%
tmp_df2
# Out:
#                                               image_name  \
# 0      ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 1      ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 2      ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 3      ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 4      ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# ...                                                  ...
# 25691  ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 25692  ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 25693  ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 25694  ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
# 25695  ./data_folder/ChatGPT_SDDB2/chatgpt-images/cha...
#
#                                                   prompt
# 0      A whimsical painting of a cat wearing a top ha...
# 1      A surreal landscape with shifting sand dunes a...
# 2      A moody nighttime scene with a lone wolf howli...
# ...

# %%
tmp_df3 = tmp_df3[['image_name', 'prompt']]
tmp_df3
# Out:
#                                               image_name  \
# 0      ./data_folder/90k_public/train_images/00000000...
# 1      ./data_folder/90k_public/train_images/00000001...
# 2      ./data_folder/90k_public/train_images/00000002...
# 3      ./data_folder/90k_public/train_images/00000003...
# 4      ./data_folder/90k_public/train_images/00000004...
# ...                                                  ...
# 81905  ./data_folder/90k_public/eval_images/00008187.jpg
# 81906  ./data_folder/90k_public/eval_images/00008188.jpg
# 81907  ./data_folder/90k_public/eval_images/00008189.jpg
# 81908  ./data_folder/90k_public/eval_images/00008190.jpg
# 81909  ./data_folder/90k_public/eval_images/00008191.jpg
#
#                                                   prompt
# 0      realistic car 3 d render sci - fi car and sci ...
# 1      a comic potrait of a female necromamcer with b...
# 2      steampunk market interior, colorful, 3 d scene...
# ...

# %%
tmp_df4
# Out:
#                                               image_name  \
# 0      ./data_folder/30k_public/artifacts/sd-img-to-p...
# 1      ./data_folder/30k_public/artifacts/sd-img-to-p...
# 2      ./data_folder/30k_public/artifacts/sd-img-to-p...
# 3      ./data_folder/30k_public/artifacts/sd-img-to-p...
# 4      ./data_folder/30k_public/artifacts/sd-img-to-p...
# ...                                                  ...
# 30024  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 30025  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 30026  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 30027  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 30028  ./data_folder/30k_public/artifacts/sd-img-to-p...
#
#                                                   prompt
# 0      a sadge - sad - pepe - the - frog, looking mor...
# 1      portrait of an italian greyhound as an italian...
# 2                            robot wearing a large scarf
# ...

# %%
df = pd.concat([tmp_df1, tmp_df2, tmp_df3, tmp_df4], axis=0)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                                image_name  \
# 0       ./data_folder/SDDB2_2M_75/SDDB2-images/dc71658...
# 1       ./data_folder/SDDB2_2M_75/SDDB2-images/9341f9e...
# 2       ./data_folder/SDDB2_2M_75/SDDB2-images/e37dbf7...
# 3       ./data_folder/SDDB2_2M_75/SDDB2-images/b5e3502...
# 4       ./data_folder/SDDB2_2M_75/SDDB2-images/09c1745...
# ...                                                   ...
# 330136  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 330137  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 330138  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 330139  ./data_folder/30k_public/artifacts/sd-img-to-p...
# 330140  ./data_folder/30k_public/artifacts/sd-img-to-p...
#
#                                                    prompt
# 0           only memories remain, trending on artstation
# 1       a painting by edward hopper of a group of men ...
# 2       a painting by edward hopper of a glowing human...
# ...

# %%
df.to_csv('all_prompt.csv', index=False)
